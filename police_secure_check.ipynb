# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\radha\Downloads\traffic_stops - traffic_stops_with_vehicle_number.csv")
# Out:
# C:\Users\radha\AppData\Local\Temp\ipykernel_48744\2037233301.py:2: DtypeWarning: Columns (0: search_type) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\radha\Downloads\traffic_stops - traffic_stops_with_vehicle_number.csv")

# %%
df.head()
# Out:
#     stop_date stop_time country_name driver_gender  driver_age_raw  \
# 0  2020-01-01   0:00:00       Canada             M              59
# 1  2020-01-01   0:01:00        India             M              35
# 2  2020-01-01   0:02:00          USA             M              26
# 3  2020-01-01   0:03:00       Canada             M              26
# 4  2020-01-01   0:04:00       Canada             M              62
#
#    driver_age driver_race     violation_raw violation  search_conducted  \
# 0          19       Asian     Drunk Driving  Speeding              True
# 1          58       Other             Other     Other             False
# 2          76       Black  Signal Violation  Speeding             False
# 3          76       Black          Speeding       DUI              True
# 4          75       Other          Speeding     Other             False
#
#       search_type stop_outcome  is_arrested stop_duration  drugs_related_stop  \
# 0  Vehicle Search       Ticket         True     16-30 Min                True
# 1  Vehicle Search       Arrest         True     16-30 Min                True
# 2           Frisk       Ticket         True     16-30 Min                True
# 3           Frisk      Warning        False      0-15 Min                True
# 4  Vehicle Search       Arrest         True     16-30 Min               False
#
#   vehicle_number
# 0     UP76DY3473
# 1     RJ83PZ4441
# 2     RJ32OM7264
# 3     RJ76TI3807
# 4     WB63BB8305

# %%
df.isnull().sum()
# Out:
# stop_date                 0
# stop_time                 0
# country_name              0
# driver_gender             0
# driver_age_raw            0
# driver_age                0
# driver_race               0
# violation_raw             0
# violation                 0
# search_conducted          0
# search_type           21720
# stop_outcome              0
# is_arrested               0
# stop_duration             0
# drugs_related_stop        0
# vehicle_number            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 65538 entries, 0 to 65537
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           65538 non-null  str
#  1   stop_time           65538 non-null  str
#  2   country_name        65538 non-null  str
#  3   driver_gender       65538 non-null  str
#  4   driver_age_raw      65538 non-null  int64
#  5   driver_age          65538 non-null  int64
#  6   driver_race         65538 non-null  str
#  7   violation_raw       65538 non-null  str
#  8   violation           65538 non-null  str
#  9   search_conducted    65538 non-null  bool
#  10  search_type         43818 non-null  str
#  11  stop_outcome        65538 non-null  str
#  12  is_arrested         65538 non-null  bool
#  13  stop_duration       65538 non-null  str
#  14  drugs_related_stop  65538 non-null  bool
#  15  vehicle_number      65538 non-null  str
# dtypes: bool(3), int64(2), str(11)
# memory usage: 6.7 MB

# %%
df['stop_date'] = pd.to_datetime(df['stop_date'], errors='coerce').dt.strftime('%Y-%m-%d')
df['stop_time'] = pd.to_datetime(df['stop_time'], errors='coerce').dt.strftime('%H:%M:%S')
# Out:
# C:\Users\radha\AppData\Local\Temp\ipykernel_48744\868971739.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['stop_time'] = pd.to_datetime(df['stop_time'], errors='coerce').dt.strftime('%H:%M:%S')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 65538 entries, 0 to 65537
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           65538 non-null  str
#  1   stop_time           65538 non-null  str
#  2   country_name        65538 non-null  str
#  3   driver_gender       65538 non-null  str
#  4   driver_age_raw      65538 non-null  int64
#  5   driver_age          65538 non-null  int64
#  6   driver_race         65538 non-null  str
#  7   violation_raw       65538 non-null  str
#  8   violation           65538 non-null  str
#  9   search_conducted    65538 non-null  bool
#  10  search_type         43818 non-null  str
#  11  stop_outcome        65538 non-null  str
#  12  is_arrested         65538 non-null  bool
#  13  stop_duration       65538 non-null  str
#  14  drugs_related_stop  65538 non-null  bool
#  15  vehicle_number      65538 non-null  str
# dtypes: bool(3), int64(2), str(11)
# memory usage: 6.7 MB

# %%
df['stop_date'] = pd.to_datetime(df['stop_date']).dt.date

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 65538 entries, 0 to 65537
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           65538 non-null  object
#  1   stop_time           65538 non-null  object
#  2   country_name        65538 non-null  str
#  3   driver_gender       65538 non-null  str
#  4   driver_age_raw      65538 non-null  int64
#  5   driver_age          65538 non-null  int64
#  6   driver_race         65538 non-null  str
#  7   violation_raw       65538 non-null  str
#  8   violation           65538 non-null  str
#  9   search_conducted    65538 non-null  bool
#  10  search_type         43818 non-null  str
#  11  stop_outcome        65538 non-null  str
#  12  is_arrested         65538 non-null  bool
#  13  stop_duration       65538 non-null  str
#  14  drugs_related_stop  65538 non-null  bool
#  15  vehicle_number      65538 non-null  str
# dtypes: bool(3), int64(2), object(2), str(9)
# memory usage: 6.7+ MB

# %%
df['stop_time'] = pd.to_datetime(df['stop_time']).dt.time
# Out:
# C:\Users\radha\AppData\Local\Temp\ipykernel_48744\3850170530.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['stop_time'] = pd.to_datetime(df['stop_time']).dt.time

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 65538 entries, 0 to 65537
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           65538 non-null  datetime64[us]
#  1   stop_time           65538 non-null  object
#  2   country_name        65538 non-null  str
#  3   driver_gender       65538 non-null  str
#  4   driver_age_raw      65538 non-null  int64
#  5   driver_age          65538 non-null  int64
#  6   driver_race         65538 non-null  str
#  7   violation_raw       65538 non-null  str
#  8   violation           65538 non-null  str
#  9   search_conducted    65538 non-null  bool
#  10  search_type         43818 non-null  str
#  11  stop_outcome        65538 non-null  str
#  12  is_arrested         65538 non-null  bool
#  13  stop_duration       65538 non-null  str
#  14  drugs_related_stop  65538 non-null  bool
#  15  vehicle_number      65538 non-null  str
# dtypes: bool(3), datetime64[us](1), int64(2), object(1), str(9)
# memory usage: 6.7+ MB

# %%
df["search_type"] = df["search_type"].fillna(df["search_type"].mode()[0])

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 65538 entries, 0 to 65537
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           65538 non-null  object
#  1   stop_time           65538 non-null  object
#  2   country_name        65538 non-null  str
#  3   driver_gender       65538 non-null  str
#  4   driver_age_raw      65538 non-null  int64
#  5   driver_age          65538 non-null  int64
#  6   driver_race         65538 non-null  str
#  7   violation_raw       65538 non-null  str
#  8   violation           65538 non-null  str
#  9   search_conducted    65538 non-null  bool
#  10  search_type         65538 non-null  str
#  11  stop_outcome        65538 non-null  str
#  12  is_arrested         65538 non-null  bool
#  13  stop_duration       65538 non-null  str
#  14  drugs_related_stop  65538 non-null  bool
#  15  vehicle_number      65538 non-null  str
# dtypes: bool(3), int64(2), object(2), str(9)
# memory usage: 6.7+ MB

# %%
df.drop(["driver_age_raw", "violation_raw"], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['stop_date', 'stop_time', 'country_name', 'driver_gender', 'driver_age',
#        'driver_race', 'violation', 'search_conducted', 'search_type',
#        'stop_outcome', 'is_arrested', 'stop_duration', 'drugs_related_stop',
#        'vehicle_number'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 65538 entries, 0 to 65537
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           65538 non-null  object
#  1   stop_time           65538 non-null  object
#  2   country_name        65538 non-null  str
#  3   driver_gender       65538 non-null  str
#  4   driver_age          65538 non-null  int64
#  5   driver_race         65538 non-null  str
#  6   violation           65538 non-null  str
#  7   search_conducted    65538 non-null  bool
#  8   search_type         65538 non-null  str
#  9   stop_outcome        65538 non-null  str
#  10  is_arrested         65538 non-null  bool
#  11  stop_duration       65538 non-null  str
#  12  drugs_related_stop  65538 non-null  bool
#  13  vehicle_number      65538 non-null  str
# dtypes: bool(3), int64(1), object(2), str(8)
# memory usage: 5.7+ MB

# %%
pip install mysql-connector-python
# Out:
# Collecting mysql-connector-python
#   Downloading mysql_connector_python-9.6.0-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Downloading mysql_connector_python-9.6.0-cp311-cp311-win_amd64.whl (16.5 MB)
#    ---------------------------------------- 0.0/16.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.5 MB ? eta -:--:--
#    --- ------------------------------------ 1.6/16.5 MB 6.5 MB/s eta 0:00:03
#    ------- -------------------------------- 3.1/16.5 MB 6.8 MB/s eta 0:00:02
#    ----------- ---------------------------- 4.7/16.5 MB 6.6 MB/s eta 0:00:02
#    -------------- ------------------------- 6.0/16.5 MB 6.6 MB/s eta 0:00:02
#    ----------------- ---------------------- 7.3/16.5 MB 6.7 MB/s eta 0:00:02
#    --------------------- ------------------ 8.9/16.5 MB 6.6 MB/s eta 0:00:02
#    ------------------------ --------------- 10.2/16.5 MB 6.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 11.8/16.5 MB 6.7 MB/s eta 0:00:01
#    ------------------------------- -------- 13.1/16.5 MB 6.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 14.4/16.5 MB 6.7 MB/s eta 0:00:01
#    -------------------------------------- - 16.0/16.5 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------  16.3/16.5 MB 6.6 MB/s eta 0:00:01
#    ---------------------------------------- 16.5/16.5 MB 5.9 MB/s  0:00:03
# Installing collected packages: mysql-connector-python
# Successfully installed mysql-connector-python-9.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector 
mydb = mysql.connector.connect(
host="localhost", 
user="root",
password="ranjanaa", 
auth_plugin='mysql_native_password' ) 
mycursor = mydb.cursor() 
mycursor.execute("CREATE DATABASE police_secure_check")

# %%
mycursor.execute("SHOW DATABASES") 
for x in mycursor: 
    print(x)
# Out:
# ('db1',)
# ('dte1',)
# ('dte12',)
# ('dte38',)
# ('information_schema',)
# ('mysql',)
# ('performance_schema',)
# ('police_secure_check',)
# ('sakila',)
# ('sys',)
# ('world',)

# %%
mycursor.execute("USE police_secure_check")  # Select database
mycursor.execute("""
    CREATE TABLE IF NOT EXISTS secure_check (
        stop_date DATE,
        stop_time TIME,
        country_name VARCHAR(50),
        driver_gender VARCHAR(10),
        driver_age INT,
        driver_race VARCHAR(50),
        violation VARCHAR(100),
        search_conducted BOOLEAN,
        search_type VARCHAR(50),
        stop_outcome VARCHAR(50),
        is_arrested BOOLEAN,
        stop_duration VARCHAR(20),
        drugs_related_stop BOOLEAN,
        vehicle_number VARCHAR(20)
    );
""")
mydb.commit()

# %%
data_list = df.values.tolist()
query = """
    INSERT INTO secure_check (stop_date, stop_time, country_name, driver_gender, driver_age, driver_race, violation, search_conducted, search_type, stop_outcome, is_arrested, stop_duration, drugs_related_stop, vehicle_number)
    VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s);
"""
mycursor.executemany(query, data_list)
mydb.commit()
